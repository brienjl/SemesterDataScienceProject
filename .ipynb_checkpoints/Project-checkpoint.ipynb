# %% [markdown]
# # Project Background - Wine Reviews
#
# This project, and the data used, is based on the dataset called "Wine Reviews" listed on [Kaggle](https://www.kaggle.com/zynicide/wine-reviews/home).
#
# The dataset contains 14 columns and 130,000 rows of wine reviews and was scraped from [WineEnthusiast](https://www.winemag.com/?s=&drink_type=wine) by Kaggler [zackthoutt](https://www.kaggle.com/zynicide) who is interested in "creating a model that can identify variety, winery, and location of a wine based on a description."
#
# ## First Impressions
# I want to see if it's possible to predict the points of a wine given a set of inputs (price, designation, country of orgin, etc). I'm thinking the description might be useful if I do some sort of unsupervised learning or something on it. There isn't much continuous data.
#
# ## Data Discussion
#
# The dataset contains 14 columns:
# * '# Number
# * Country: The country that the wine is from
# * Description: A few sentences form a sommelier describing the wine's taste, smell, look, feel, etc.
# * Designation: The vineyard within the winery where the grapes that made the wine are from.
# * Points: the number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post reviews of wines that score greater than 80).
# * Price: The cost for a bottle of wine
# * Provice: The state or provice that the wine is from
# * Region_1: The growing area in a provice or state
# * Region_2: Sometimes there are more specific regions specific within a wine growing area (can contain NULL Values)
# * Taster_name: Name of the person who tasted and reviewed the wine.
# * Taster_twitter_handle: Twitter handle for the person who tasted and reviewed the wine
# * Title: The title of the wine review, which often contains the vintage if you're interested in extracted that feature
# * Variety: The type of grapes used to make the win (i.e. Pinot Noir)

# %% [markdown]
# ### Import Libraries

# %%
# I like to stash the imports at the top so readers know what dependencies exist
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Userful Functions
# Some Functions I created to clean up some of the code later on

# %%
# Simple Function to Find What Data is Missing 
# Input = Some Data
# Transformation = Find the total number of missing Values
# Return Missing Data as a Total Number and as a Percent of The Input
def missingData (data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    missing_data = pd.concat([total, percent], axis = 1, keys = ['Total', 'Percent'])
    return missing_data

# %% [markdown]
# #### Read in the data

# %%
df = pd.read_csv('winemag-data-130k-v2.csv')
df.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# ### Thoughts
# Because the points is something I want to predict, I'm going to move it to the end of the DataFrame to make my life easier

# %%
X = df.iloc[:,[0,1,2,3,5,6,7,8,9,10,11,12,13]]
y = df.iloc[:,[4]].values

df_x = pd.DataFrame(X)
df_y = pd.DataFrame(y, columns = ['points'])

df = pd.concat([df_x,df_y], axis = 1)
df.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  price           province  \
# 0                        Vulkà Bianco    NaN  Sicily & Sardinia
# 1                            Avidagos   15.0              Douro
# 2                                 NaN   14.0             Oregon
# 3                Reserve Late Harvest   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  points
# 0     White Blend              Nicosia      87
# 1  Portuguese Red  Quinta dos Avidagos      87
# 2      Pinot Gris            Rainstorm      87
# 3        Riesling           St. Julian      87
# 4      Pinot Noir         Sweet Cheeks      87

# %% [markdown]
# ## Data Cleansing

# %% [markdown]
# #### Check for Duplicate Data
# I want to check for duplicate data -- most likely get rid of it considering this was scraped from a website it might not be clean. I'll check by "Description" because this would be the most unique

# %%
df[df.duplicated('description', keep = False)].sort_values('description')
# Out:
#         Unnamed: 0      country  \
# 67614        67614           US
# 46540        46540           US
# 119702      119702           US
# 72181        72181           US
# 73731        73731       France
# 100745      100745       France
# 73730        73730       France
# 100744      100744       France
# 73729        73729       France
# 100743      100743       France
# 4666          4666       France
# 100725      100725       France
# 107873      107873       France
# 23956        23956       France
# 100655      100655       France
# 81866        81866       France
# 100654      100654       France
# 81865        81865       France
# 100653      100653       France
# 81864        81864       France
# 71853        71853       France
# 71851        71851       France
# 34343        34343       France
# 92150        92150       France
# 105554      105554       France
# 105559      105559       France
# 55450        55450           US
# 77609        77609           US
# 17024        17024           US
# 26740        26740           US
# ...            ...          ...
# 36629        36629      Austria
# 37128        37128      Austria
# 98282        98282      Germany
# 56825        56825      Germany
# 25764        25764      Germany
# 79997        79997      Germany
# 30171        30171      Germany
# 114548      114548      Germany
# 119968      119968      Germany
# 40160        40160      Germany
# 31665        31665           US
# 35801        35801           US
# 114892      114892           US
# 29776        29776           US
# 86953        86953        Italy
# 95747        95747        Italy
# 88999        88999      Austria
# 109172      109172      Austria
# 121126      121126           US
# 48542        48542           US
# 103573      103573  New Zealand
# 77536        77536  New Zealand
# 13869        13869        Italy
# 23271        23271        Italy
# 34154        34154        Italy
# 13889        13889        Italy
# 129801      129801        Italy
# 87891        87891        Italy
# 91976        91976       Canada
# 19401        19401       Canada
#
#                                               description  \
# 67614   100% Malbec, it's redolent with dark plums, wi...
# 46540   100% Malbec, it's redolent with dark plums, wi...
# 119702  100% Sangiovese, this pale pink wine has notes...
# 72181   100% Sangiovese, this pale pink wine has notes...
# 73731   87-89 Barrel sample. A pleasurable, perfumed w...
# 100745  87-89 Barrel sample. A pleasurable, perfumed w...
# 73730   87-89 Barrel sample. Minty aromas give lifted ...
# 100744  87-89 Barrel sample. Minty aromas give lifted ...
# 73729   87-89 Barrel sample. With its lovely fresh fru...
# 100743  87-89 Barrel sample. With its lovely fresh fru...
# 4666    88-90 Barrel sample. With its minty aroma and ...
# 100725  88-90 Barrel sample. With its minty aroma and ...
# 107873  88-90 Solid, chunky wine, firmly tannic and to...
# 23956   88-90 Solid, chunky wine, firmly tannic and to...
# 100655  89-91 Barrel sample. Dark, somewhat austere, a...
# 81866   89-91 Barrel sample. Dark, somewhat austere, a...
# 100654  89—91 Barrel sample. The top wine produced by ...
# 81865   89—91 Barrel sample. The top wine produced by ...
# 100653  89—91 Barrel sample. Very rich fruit, very rip...
# 81864   89—91 Barrel sample. Very rich fruit, very rip...
# 71853   90–92. Barrel sample. This is a solid and dens...
# 71851   90–92. Barrel sample. This is a solid and dens...
# 34343   92-94. Barrel sample. DA dark, dry wine that s...
# 92150   92-94. Barrel sample. DA dark, dry wine that s...
# 105554  92–94. Barrel sample. With so much spicy fruit...
# 105559  92–94. Barrel sample. With so much spicy fruit...
# 55450   A 100% varietal wine fermented in stainless st...
# 77609   A 100% varietal wine fermented in stainless st...
# 17024   A 100% varietal wine from near the town of Gle...
# 26740   A 100% varietal wine from near the town of Gle...
# ...                                                   ...
# 36629   Zesty green citrus with lifted notes of Confer...
# 37128   Zesty green citrus with lifted notes of Confer...
# 98282   Zesty lemon and lime acidity takes center stag...
# 56825   Zesty lemon and lime acidity takes center stag...
# 25764   Zesty lemon and lime aromas add elegance to un...
# 79997   Zesty lemon and lime aromas add elegance to un...
# 30171   Zesty lime cuts razor-sharp edges into this bu...
# 114548  Zesty lime cuts razor-sharp edges into this bu...
# 119968  Zesty lime pith and lemon notes abound in this...
# 40160   Zesty lime pith and lemon notes abound in this...
# 31665   Zin fans should pick up this winery's entire r...
# 35801   Zin fans should pick up this winery's entire r...
# 114892  Zinfandel fans will celebrate this powerfully ...
# 29776   Zinfandel fans will celebrate this powerfully ...
# 86953   Zorzettig's precious Picolit dessert wine deli...
# 95747   Zorzettig's precious Picolit dessert wine deli...
# 88999   Zweigelt can do easy-drinking styles but in th...
# 109172  Zweigelt can do easy-drinking styles but in th...
# 121126  lean and zesty Chardonnay with a burst of mout...
# 48542   lean and zesty Chardonnay with a burst of mout...
# 103573  this medium-bodied Sauvignon Blanc shows only ...
# 77536   this medium-bodied Sauvignon Blanc shows only ...
# 13869   ‘Na Vota is a fresh and easygoing wine that is...
# 23271   ‘Na Vota is a fresh and easygoing wine that is...
# 34154   “Fresh and dry” is what the wine label adverti...
# 13889   “Fresh and dry” is what the wine label adverti...
# 129801  “Il Bugiardo,” which is Italian for “the liar,...
# 87891   “Il Bugiardo,” which is Italian for “the liar,...
# 91976   “Open and drink” the instructions should read,...
# 19401   “Open and drink” the instructions should read,...
#
#                                               designation  price  \
# 67614                                                 NaN   20.0
# 46540                                                 NaN   20.0
# 119702                                             Meadow   18.0
# 72181                                              Meadow   18.0
# 73731                                       Barrel sample    NaN
# 100745                                      Barrel sample    NaN
# 73730                                       Barrel sample    NaN
# 100744                                      Barrel sample    NaN
# 73729                                       Barrel sample    NaN
# 100743                                      Barrel sample    NaN
# 4666                                        Barrel sample    NaN
# 100725                                      Barrel sample    NaN
# 107873                                      Barrel sample    NaN
# 23956                                       Barrel sample    NaN
# 100655                                      Barrel sample    NaN
# 81866                                       Barrel sample    NaN
# 100654                                      Barrel sample    NaN
# 81865                                       Barrel sample    NaN
# 100653                                      Barrel sample    NaN
# 81864                                       Barrel sample    NaN
# 71853                                       Barrel Sample    NaN
# 71851                                       Barrel Sample    NaN
# 34343                                       Barrel Sample    NaN
# 92150                                       Barrel Sample    NaN
# 105554                                      Barrel Sample    NaN
# 105559                                      Barrel Sample    NaN
# 55450                              Woods Vineyard Rosé of   29.0
# 77609                              Woods Vineyard Rosé of   29.0
# 17024                                        Estate Grown   32.0
# 26740                                        Estate Grown   32.0
# ...                                                   ...    ...
# 36629                                       Kittmannsberg   14.0
# 37128                                       Kittmannsberg   14.0
# 98282                                   Semi Dry Kabinett   25.0
# 56825                                   Semi Dry Kabinett   25.0
# 25764   Nik Weis Wiltinger Alte Reben Ortswein Kabinet...   19.0
# 79997   Nik Weis Wiltinger Alte Reben Ortswein Kabinet...   19.0
# 30171              Kaseler Nies'chen Kabinett Grosse Lage   26.0
# 114548             Kaseler Nies'chen Kabinett Grosse Lage   26.0
# 119968                   Hattenheim Schützenhaus Kabinett   19.0
# 40160                    Hattenheim Schützenhaus Kabinett   19.0
# 31665                                           Clevenger   38.0
# 35801                                           Clevenger   38.0
# 114892               Old Vine Fanucchi-Wood Road Vineyard   55.0
# 29776                Old Vine Fanucchi-Wood Road Vineyard   55.0
# 86953                                                 NaN    NaN
# 95747                                                 NaN    NaN
# 88999                                          Heideboden   26.0
# 109172                                         Heideboden   26.0
# 121126                                                NaN    7.0
# 48542                                                 NaN    7.0
# 103573                                                NaN   15.0
# 77536                                                 NaN   15.0
# 13869                                            'Na Vota   18.0
# 23271                                            'Na Vota   18.0
# 34154                                         White Label   23.0
# 13889                                         White Label   23.0
# 129801                                        Il Bugiardo   36.0
# 87891                                         Il Bugiardo   36.0
# 91976                                                 NaN   20.0
# 19401                                                 NaN   20.0
#
#                   province                                 region_1  \
# 67614           Washington                        Rattlesnake Hills
# 46540           Washington                        Rattlesnake Hills
# 119702          Washington                     Columbia Valley (WA)
# 72181           Washington                     Columbia Valley (WA)
# 73731             Bordeaux                             Saint-Julien
# 100745            Bordeaux                             Saint-Julien
# 73730             Bordeaux                            Saint-Émilion
# 100744            Bordeaux                            Saint-Émilion
# 73729             Bordeaux                       Lalande de Pomerol
# 100743            Bordeaux                       Lalande de Pomerol
# 4666              Bordeaux                                  Margaux
# 100725            Bordeaux                                  Margaux
# 107873            Bordeaux                               Haut-Médoc
# 23956             Bordeaux                               Haut-Médoc
# 100655            Bordeaux                             Saint-Julien
# 81866             Bordeaux                             Saint-Julien
# 100654            Bordeaux                            Saint-Émilion
# 81865             Bordeaux                            Saint-Émilion
# 100653            Bordeaux                                Sauternes
# 81864             Bordeaux                                Sauternes
# 71853             Bordeaux                          Moulis-en-Médoc
# 71851             Bordeaux                                  Margaux
# 34343             Bordeaux                            Saint-Émilion
# 92150             Bordeaux                            Saint-Émilion
# 105554            Bordeaux                                 Pauillac
# 105559            Bordeaux                             Saint-Julien
# 55450           California                     Russian River Valley
# 77609           California                     Russian River Valley
# 17024           California                            Sonoma Valley
# 26740           California                            Sonoma Valley
# ...                    ...                                      ...
# 36629              Kamptal                                      NaN
# 37128              Kamptal                                      NaN
# 98282             Rheingau                                      NaN
# 56825             Rheingau                                      NaN
# 25764                Mosel                                      NaN
# 79997                Mosel                                      NaN
# 30171                Mosel                                      NaN
# 114548               Mosel                                      NaN
# 119968            Rheingau                                      NaN
# 40160             Rheingau                                      NaN
# 31665           California                              Paso Robles
# 35801           California                              Paso Robles
# 114892          California                     Russian River Valley
# 29776           California                     Russian River Valley
# 86953   Northeastern Italy               Colli Orientali del Friuli
# 95747   Northeastern Italy               Colli Orientali del Friuli
# 88999           Burgenland                                      NaN
# 109172          Burgenland                                      NaN
# 121126          California                               California
# 48542           California                               California
# 103573         New Zealand                                      NaN
# 77536          New Zealand                                      NaN
# 13869             Piedmont           Ruché di Castagnole Monferrato
# 23271             Piedmont           Ruché di Castagnole Monferrato
# 34154             Piedmont                                     Gavi
# 13889             Piedmont                                     Gavi
# 129801              Veneto  Valpolicella Classico Superiore Ripasso
# 87891               Veneto  Valpolicella Classico Superiore Ripasso
# 91976     British Columbia                          Okanagan Valley
# 19401     British Columbia                          Okanagan Valley
#
#                 region_2         taster_name taster_twitter_handle  \
# 67614    Columbia Valley    Sean P. Sullivan         @wawinereport
# 46540    Columbia Valley    Sean P. Sullivan         @wawinereport
# 119702   Columbia Valley    Sean P. Sullivan         @wawinereport
# 72181    Columbia Valley    Sean P. Sullivan         @wawinereport
# 73731                NaN          Roger Voss            @vossroger
# 100745               NaN          Roger Voss            @vossroger
# 73730                NaN          Roger Voss            @vossroger
# 100744               NaN          Roger Voss            @vossroger
# 73729                NaN          Roger Voss            @vossroger
# 100743               NaN          Roger Voss            @vossroger
# 4666                 NaN          Roger Voss            @vossroger
# 100725               NaN          Roger Voss            @vossroger
# 107873               NaN          Roger Voss            @vossroger
# 23956                NaN          Roger Voss            @vossroger
# 100655               NaN          Roger Voss            @vossroger
# 81866                NaN          Roger Voss            @vossroger
# 100654               NaN          Roger Voss            @vossroger
# 81865                NaN          Roger Voss            @vossroger
# 100653               NaN          Roger Voss            @vossroger
# 81864                NaN          Roger Voss            @vossroger
# 71853                NaN          Roger Voss            @vossroger
# 71851                NaN          Roger Voss            @vossroger
# 34343                NaN          Roger Voss            @vossroger
# 92150                NaN          Roger Voss            @vossroger
# 105554               NaN          Roger Voss            @vossroger
# 105559               NaN          Roger Voss            @vossroger
# 55450             Sonoma      Virginie Boone               @vboone
# 77609             Sonoma      Virginie Boone               @vboone
# 17024             Sonoma      Virginie Boone               @vboone
# 26740             Sonoma      Virginie Boone               @vboone
# ...                  ...                 ...                   ...
# 36629                NaN    Anne Krebiehl MW           @AnneInVino
# 37128                NaN    Anne Krebiehl MW           @AnneInVino
# 98282                NaN  Anna Lee C. Iijima                   NaN
# 56825                NaN  Anna Lee C. Iijima                   NaN
# 25764                NaN  Anna Lee C. Iijima                   NaN
# 79997                NaN  Anna Lee C. Iijima                   NaN
# 30171                NaN  Anna Lee C. Iijima                   NaN
# 114548               NaN  Anna Lee C. Iijima                   NaN
# 119968               NaN  Anna Lee C. Iijima                   NaN
# 40160                NaN  Anna Lee C. Iijima                   NaN
# 31665      Central Coast       Matt Kettmann         @mattkettmann
# 35801      Central Coast       Matt Kettmann         @mattkettmann
# 114892            Sonoma                 NaN                   NaN
# 29776             Sonoma                 NaN                   NaN
# 86953                NaN                 NaN                   NaN
# 95747                NaN                 NaN                   NaN
# 88999                NaN    Anne Krebiehl MW           @AnneInVino
# 109172               NaN    Anne Krebiehl MW           @AnneInVino
# 121126  California Other                 NaN                   NaN
# 48542   California Other                 NaN                   NaN
# 103573               NaN      Joe Czerwinski                @JoeCz
# 77536                NaN      Joe Czerwinski                @JoeCz
# 13869                NaN                 NaN                   NaN
# 23271                NaN                 NaN                   NaN
# 34154                NaN                 NaN                   NaN
# 13889                NaN                 NaN                   NaN
# 129801               NaN                 NaN                   NaN
# 87891                NaN                 NaN                   NaN
# 91976                NaN        Paul Gregutt           @paulgwine
# 19401                NaN        Paul Gregutt           @paulgwine
#
#                                                     title  \
# 67614          Roza Ridge 2010 Malbec (Rattlesnake Hills)
# 46540          Roza Ridge 2010 Malbec (Rattlesnake Hills)
# 119702  Ross Andrew 2013 Meadow Rosé (Columbia Valley ...
# 72181   Ross Andrew 2013 Meadow Rosé (Columbia Valley ...
# 73731   Château Lalande-Borie 2008 Barrel sample  (Sai...
# 100745  Château Lalande-Borie 2008 Barrel sample  (Sai...
# 73730   Château Haut-Sarpe 2008 Barrel sample  (Saint-...
# 100744  Château Haut-Sarpe 2008 Barrel sample  (Saint-...
# 73729   Château Bertineau Saint-Vincent 2008 Barrel sa...
# 100743  Château Bertineau Saint-Vincent 2008 Barrel sa...
# 4666       Château Ferrière 2008 Barrel sample  (Margaux)
# 100725     Château Ferrière 2008 Barrel sample  (Margaux)
# 107873    Château Cissac 2010 Barrel sample  (Haut-Médoc)
# 23956     Château Cissac 2010 Barrel sample  (Haut-Médoc)
# 100655  Château Branaire-Ducru 2008 Barrel sample  (Sa...
# 81866   Château Branaire-Ducru 2008 Barrel sample  (Sa...
# 100654  Château Lassègue 2006 Barrel sample  (Saint-Ém...
# 81865   Château Lassègue 2006 Barrel sample  (Saint-Ém...
# 100653    Château Caillou 2006 Barrel sample  (Sauternes)
# 81864     Château Caillou 2006 Barrel sample  (Sauternes)
# 71853   Château Maucaillou 2012 Barrel Sample  (Moulis...
# 71851   Château Pontac-Lynch 2012 Barrel Sample  (Marg...
# 34343   Château Magdelaine 2011 Barrel Sample  (Saint-...
# 92150   Château Magdelaine 2011 Barrel Sample  (Saint-...
# 105554  Château Grand-Puy-Lacoste 2012 Barrel Sample  ...
# 105559  Château Gruaud Larose 2012 Barrel Sample  (Sai...
# 55450   Ousterhout 2015 Woods Vineyard Rosé of Pinot N...
# 77609   Ousterhout 2015 Woods Vineyard Rosé of Pinot N...
# 17024   Dunbar 2013 Estate Grown Zinfandel (Sonoma Val...
# 26740   Dunbar 2013 Estate Grown Zinfandel (Sonoma Val...
# ...                                                   ...
# 36629   Nastl 2014 Kittmannsberg Grüner Veltliner (Kam...
# 37128   Nastl 2014 Kittmannsberg Grüner Veltliner (Kam...
# 98282   Schloss Vollrads 2015 Semi Dry Kabinett Riesli...
# 56825   Schloss Vollrads 2015 Semi Dry Kabinett Riesli...
# 25764   St. Urbans-Hof 2012 Nik Weis Wiltinger Alte Re...
# 79997   St. Urbans-Hof 2012 Nik Weis Wiltinger Alte Re...
# 30171   Reichsgraf von Kesselstatt 2014 Kaseler Nies'c...
# 114548  Reichsgraf von Kesselstatt 2014 Kaseler Nies'c...
# 119968  Balthasar Ress 2015 Hattenheim Schützenhaus Ka...
# 40160   Balthasar Ress 2015 Hattenheim Schützenhaus Ka...
# 31665   Peachy Canyon 2012 Clevenger Zinfandel (Paso R...
# 35801   Peachy Canyon 2012 Clevenger Zinfandel (Paso R...
# 114892  Hartford Court 2011 Old Vine Fanucchi-Wood Roa...
# 29776   Hartford Court 2011 Old Vine Fanucchi-Wood Roa...
# 86953   Zorzettig 2006 Picolit (Colli Orientali del Fr...
# 95747   Zorzettig 2006 Picolit (Colli Orientali del Fr...
# 88999   Nittnaus Hans und Christine 2013 Heideboden Zw...
# 109172  Nittnaus Hans und Christine 2013 Heideboden Zw...
# 121126             Eye Candy 2012 Chardonnay (California)
# 48542              Eye Candy 2012 Chardonnay (California)
# 103573  Tussock Jumper 2016 Sauvignon Blanc (New Zealand)
# 77536   Tussock Jumper 2016 Sauvignon Blanc (New Zealand)
# 13869   Cantine Sant'Agata 2007 'Na Vota  (Ruché di Ca...
# 23271   Cantine Sant'Agata 2007 'Na Vota  (Ruché di Ca...
# 34154                  La Scolca 2006 White Label  (Gavi)
# 13889                  La Scolca 2006 White Label  (Gavi)
# 129801  Buglioni 2009 Il Bugiardo  (Valpolicella Class...
# 87891   Buglioni 2009 Il Bugiardo  (Valpolicella Class...
# 91976      Quails' Gate 2012 Chardonnay (Okanagan Valley)
# 19401      Quails' Gate 2012 Chardonnay (Okanagan Valley)
#
#                               variety                           winery  points
# 67614                          Malbec                       Roza Ridge      87
# 46540                          Malbec                       Roza Ridge      87
# 119702                           Rosé                      Ross Andrew      88
# 72181                            Rosé                      Ross Andrew      88
# 73731        Bordeaux-style Red Blend            Château Lalande-Borie      88
# 100745       Bordeaux-style Red Blend            Château Lalande-Borie      88
# 73730        Bordeaux-style Red Blend               Château Haut-Sarpe      88
# 100744       Bordeaux-style Red Blend               Château Haut-Sarpe      88
# 73729        Bordeaux-style Red Blend  Château Bertineau Saint-Vincent      88
# 100743       Bordeaux-style Red Blend  Château Bertineau Saint-Vincent      88
# 4666         Bordeaux-style Red Blend                 Château Ferrière      89
# 100725       Bordeaux-style Red Blend                 Château Ferrière      89
# 107873       Bordeaux-style Red Blend                   Château Cissac      89
# 23956        Bordeaux-style Red Blend                   Château Cissac      89
# 100655       Bordeaux-style Red Blend           Château Branaire-Ducru      90
# 81866        Bordeaux-style Red Blend           Château Branaire-Ducru      90
# 100654       Bordeaux-style Red Blend                 Château Lassègue      90
# 81865        Bordeaux-style Red Blend                 Château Lassègue      90
# 100653     Bordeaux-style White Blend                  Château Caillou      90
# 81864      Bordeaux-style White Blend                  Château Caillou      90
# 71853        Bordeaux-style Red Blend               Château Maucaillou      91
# 71851        Bordeaux-style Red Blend             Château Pontac-Lynch      91
# 34343        Bordeaux-style Red Blend               Château Magdelaine      93
# 92150        Bordeaux-style Red Blend               Château Magdelaine      93
# 105554       Bordeaux-style Red Blend        Château Grand-Puy-Lacoste      93
# 105559       Bordeaux-style Red Blend            Château Gruaud Larose      93
# 55450                      Pinot Noir                       Ousterhout      88
# 77609                      Pinot Noir                       Ousterhout      88
# 17024                       Zinfandel                           Dunbar      90
# 26740                       Zinfandel                           Dunbar      90
# ...                               ...                              ...     ...
# 36629                Grüner Veltliner                            Nastl      91
# 37128                Grüner Veltliner                            Nastl      91
# 98282                        Riesling                 Schloss Vollrads      91
# 56825                        Riesling                 Schloss Vollrads      91
# 25764                        Riesling                   St. Urbans-Hof      91
# 79997                        Riesling                   St. Urbans-Hof      91
# 30171                        Riesling       Reichsgraf von Kesselstatt      92
# 114548                       Riesling       Reichsgraf von Kesselstatt      92
# 119968                       Riesling                   Balthasar Ress      91
# 40160                        Riesling                   Balthasar Ress      91
# 31665                       Zinfandel                    Peachy Canyon      89
# 35801                       Zinfandel                    Peachy Canyon      89
# 114892                      Zinfandel                   Hartford Court      92
# 29776                       Zinfandel                   Hartford Court      92
# 86953                         Picolit                        Zorzettig      90
# 95747                         Picolit                        Zorzettig      90
# 88999                        Zweigelt      Nittnaus Hans und Christine      90
# 109172                       Zweigelt      Nittnaus Hans und Christine      90
# 121126                     Chardonnay                        Eye Candy      84
# 48542                      Chardonnay                        Eye Candy      84
# 103573                Sauvignon Blanc                   Tussock Jumper      88
# 77536                 Sauvignon Blanc                   Tussock Jumper      88
# 13869                           Ruché               Cantine Sant'Agata      85
# 23271                           Ruché               Cantine Sant'Agata      85
# 34154                         Cortese                        La Scolca      84
# 13889                         Cortese                        La Scolca      84
# 129801  Corvina, Rondinella, Molinara                         Buglioni      88
# 87891   Corvina, Rondinella, Molinara                         Buglioni      88
# 91976                      Chardonnay                     Quails' Gate      89
# 19401                      Chardonnay                     Quails' Gate      89
#
# [20026 rows x 14 columns]

# %%
df = df.drop_duplicates('description')
df.shape
# Out:
# (119955, 14)

# %% [markdown]
# Leaves us with about 120k rows of data

# %% [markdown]
# #### Check for NULL Values
# I'm also thinking we should see what values are 'NaN' -- Either I'll drop them or impute the data depending on what the feature is.

# %%
print(df.shape)
missingData(df)
# Out:
# (119955, 14)
#                        Total    Percent
# region_2               73195  61.018715
# designation            34532  28.787462
# taster_twitter_handle  29441  24.543370
# taster_name            24912  20.767788
# region_1               19558  16.304448
# price                   8388   6.992622
# province                  59   0.049185
# country                   59   0.049185
# variety                    1   0.000834
# points                     0   0.000000
# winery                     0   0.000000
# title                      0   0.000000
# description                0   0.000000
# Unnamed: 0                 0   0.000000

# %% [markdown]
# #### Thoughts
# I'm not too concerned about region_2. I looked into the data and this is more of an optional descriptor. Additionally, I'm not going to worry about the missing twitter handle or twitter name fields for now. Once I get into Feature Engineering, I'll determine if those are useful or not.
#
# *price:* I do need to take care of the missing "price" data. That'll most likely be something we use but I would like to do some EDA first. I'm leaning towards just dropping it but let's do some visualization first. If my results are too good, I'll use the missing prices values to regularlize the dataset.
#
# *province & country:* I would naturally think these values are important. Things like tarrifs, fixed & variable costs being greater at smaller wineries, and taxes all add to the cost of the wine. I'm going to drop these missing values. I could cross reference province and country but it seems like they're both missing for every record. There's only 59 records so not a big deal.
#
# *variety:* 1 record missing. I'll drop that too.
#
# I can probably drop that Unnamed column too.

# %%
df = df.drop(columns=['Unnamed: 0'])
df = df.reset_index(drop=True)

df = df.dropna(subset=['province'])
df = df.reset_index(drop=True)

df = df.dropna(subset=['country'])
df = df.reset_index(drop=True)

df = df.dropna(subset=['variety'])
df = df.reset_index(drop=True)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Let's have a look at the statistics of the DataFrame

# %%
df.describe()
# Out:
#                price         points
# count  111511.000000  119895.000000
# mean       35.626073      88.442204
# std        42.116495       3.093401
# min         4.000000      80.000000
# 25%        17.000000      86.000000
# 50%        25.000000      88.000000
# 75%        42.000000      91.000000
# max      3300.000000     100.000000

# %% [markdown]
# #### Thoughts
# The two features we can get statistics on are Points and Price (being that they're continuous values).
#
# *Points:* Looks like the mean and mediun are roughly the same. The are only between 80-100. I looked into this and the website doesn't post reviews of wines that score less than 80 points.
#
# *Price:* We have a wine that costs $3300. That's definately some walking around money! The standard deviation seems kind of large. Might want to look deeper into this and see if there's more high priced wines skewing this. Referring back to above, About 7 percent of the data is a missing price. I think i'm just going to drop these values for now. I'm more concerned about seeing the price distribution.

# %%
# Drop the NaN Prices
df=df.dropna(subset=['price'])
df=df.reset_index(drop=True)
print(df.shape)
missingData(df)
# Out:
# (111511, 13)
#                        Total    Percent
# region_2               64952  58.247168
# designation            32039  28.731695
# taster_twitter_handle  27750  24.885437
# taster_name            23267  20.865206
# region_1               17955  16.101551
# points                     0   0.000000
# winery                     0   0.000000
# variety                    0   0.000000
# title                      0   0.000000
# province                   0   0.000000
# price                      0   0.000000
# description                0   0.000000
# country                    0   0.000000

# %% [markdown]
# #### Distribution of Price
# Because we know points has a relatively normal distrubtion we don't really need to visualize that, but price is probably skewed with some fancy/expensive wines so let's try to visualize the distribution.

# %%
plt.figure(figsize=(20,5))
plt.title("Prices")
x = sns.distplot(df['price'])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### Thoughts
# There aren't too many expensive wines but they're definately skewing things. Let's see which ones we can get rid of while we're looking at it. Let's loop through a few calculations to find a sweet spot and drop the expensive wines.

# %%
x = 95
while (x < 350):
    percent = df[df['price']>x].shape[0]/df.shape[0]*100
    print(percent, "% of wines are more expensive than ", "$",x,)
    x = x + 10
# Out:
# 3.558393342360843 % of wines are more expensive than  $ 95
# 2.7154271775878613 % of wines are more expensive than  $ 105
# 2.32712467828286 % of wines are more expensive than  $ 115
# 1.7648483109289668 % of wines are more expensive than  $ 125
# 1.4994036462770488 % of wines are more expensive than  $ 135
# 1.3021136928195425 % of wines are more expensive than  $ 145
# 1.0277013030104654 % of wines are more expensive than  $ 155
# 0.9281595537659961 % of wines are more expensive than  $ 165
# 0.7981275389871851 % of wines are more expensive than  $ 175
# 0.741630870497081 % of wines are more expensive than  $ 185
# 0.6896180645855566 % of wines are more expensive than  $ 195
# 0.5918698603725193 % of wines are more expensive than  $ 205
# 0.5595860498067455 % of wines are more expensive than  $ 215
# 0.5066764713795051 % of wines are more expensive than  $ 225
# 0.4761862058451633 % of wines are more expensive than  $ 235
# 0.4483862578579692 % of wines are more expensive than  $ 245
# 0.38919927182071723 % of wines are more expensive than  $ 255
# 0.36767673144353474 % of wines are more expensive than  $ 265
# 0.34794773609778407 % of wines are more expensive than  $ 275
# 0.334496148362045 % of wines are more expensive than  $ 285
# 0.3147671530162943 % of wines are more expensive than  $ 295
# 0.27261884477764525 % of wines are more expensive than  $ 305
# 0.261857574589054 % of wines are more expensive than  $ 315
# 0.24033503421187147 % of wines are more expensive than  $ 325
# 0.2295737640232802 % of wines are more expensive than  $ 335
# 0.2295737640232802 % of wines are more expensive than  $ 345

# %% [markdown]
# #### Thoughts
# I'm thinking the sweet spot will be around 255 dollars. With only 0.3890 percent of the wines being greater than 255, we can drop this and see what we have.

# %%
df = df[df.price < 255]
df=df.reset_index(drop=True)
print(df.shape)
missingData(df)
# Out:
# (111071, 13)
#                        Total    Percent
# region_2               64552  58.117781
# designation            31877  28.699661
# taster_twitter_handle  27675  24.916495
# taster_name            23215  20.901045
# region_1               17886  16.103213
# points                     0   0.000000
# winery                     0   0.000000
# variety                    0   0.000000
# title                      0   0.000000
# province                   0   0.000000
# price                      0   0.000000
# description                0   0.000000
# country                    0   0.000000

# %%
print(df.shape)
plt.figure(figsize=(20,5))
plt.title("Prices")
x = sns.distplot(df['price'])
# Out:
# (111071, 13)
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df.describe()
# Out:
#                price         points
# count  111071.000000  111071.000000
# mean       33.960683      88.388787
# std        26.557020       3.075890
# min         4.000000      80.000000
# 25%        17.000000      86.000000
# 50%        25.000000      88.000000
# 75%        42.000000      91.000000
# max       253.000000     100.000000

# %% [markdown]
# #### Thoughts
# The mean and medium for price are now a little bit tighter and the standard deviation came down, this'll probably help us get more accurate results now that we don't have any outliers. Might still be a good idea to use a scaler

# %% [markdown]
# #### Visualizing price and points by  the top 20 Counties

# %%
top = df.groupby(['country'])['price','points'].mean().reset_index().sort_values('price', ascending=False)
top20 = top[['country','points','price']].head(n=20)
top20
# Out:
#         country     points      price
# 37  Switzerland  88.500000  72.833333
# 13      England  91.762712  52.677966
# 21        Italy  88.609840  38.435989
# 39           US  88.552910  36.398673
# 16      Germany  89.790078  36.071540
# 7        Canada  89.312500  35.776786
# 14       France  88.657009  35.539813
# 18      Hungary  89.174603  34.301587
# 2     Australia  88.533364  33.111214
# 20       Israel  88.470199  31.770419
# 3       Austria  90.218232  30.921468
# 22      Lebanon  87.593750  30.281250
# 36        Spain  87.218905  27.035489
# 28  New Zealand  88.303226  26.833065
# 25       Mexico  85.161765  26.470588
# 41      Uruguay  86.663265  26.326531
# 34     Slovenia  88.071429  25.542857
# 10      Croatia  87.323529  25.529412
# 38       Turkey  88.074074  24.950617
# 32       Serbia  87.625000  24.875000

# %%
plot = plt.scatter(top20.iloc[:,1], top20.iloc[:,2])
plt.title("Top 20 Countries: Wine Points by Wine Price ")
plt.xlabel('Wine Points')
plt.ylabel('Wine Price')
plt.show()
plt.close()

# %% [markdown]
# #### Looks like there's some correlation between price and points

# %% [markdown]
# #### Variety of Wines
# I was looking through the raw data and there seems to be a wide variety of wines. Let's have a look.

# %%
data = df.groupby('variety').filter(lambda x: len(x) >100)
list = data.variety.value_counts().index.tolist()
fig, ax = plt.subplots(figsize = (20,7))
sns.countplot(x='variety', data=data, order = list, ax = ax)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Thoughts
# It looks like there's a lot of wines here from all sorts of languages and cultures. I would have to do some research or find a way to translate. Wines like "pinot nero" are probably a pinot noir. Safe bet would be to pick the wines varieties with lots of observations. Looks like 1500 would be a good cut off point
#
# #### Create variety_df : Where observations > 1500

# %%
variety_df = df.groupby('variety').filter(lambda x: len(x) > 1500)
varieties = variety_df['variety'].value_counts().index.tolist()

print(variety_df.shape)
variety_df['variety'].unique()
# Out:
# (78536, 13)
# array(['Portuguese Red', 'Riesling', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Chardonnay', 'Malbec', 'Red Blend', 'White Blend', 'Merlot',
#        'Sauvignon Blanc', 'Sangiovese', 'Bordeaux-style Red Blend',
#        'Rosé', 'Zinfandel', 'Syrah', 'Nebbiolo', 'Sparkling Blend',
#        'Tempranillo'], dtype=object)

# %% [markdown]
# #### Thoughts
# This gives us about 15 wines to play with. I think I'm going to hold onto variety_df and use it going forward

# %% [markdown]
# #### Visualizing Country Data

# %%
data = df.groupby('country').filter(lambda x: len(x) >100)
list = data.country.value_counts().index.tolist()
fig, ax = plt.subplots(figsize = (20,7))
sns.countplot(x='country', data=data, order = list, ax = ax)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Hypothesis Test, Feature Engineering & Model Selection
#
# ### Hypothesis
#
# * H0: There is no predictive value in the description of a wine and the amount of points it recieves
# * H1: There is predictive value in the description and the points a wine recieves

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Create a New DataFrame using selected Features where the variety > 1500 observations

# %%
data = variety_df[['country','price', 'description','points']]
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78536 entries, 0 to 111067
# Data columns (total 4 columns):
# country        78536 non-null object
# price          78536 non-null float64
# description    78536 non-null object
# points         78536 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.0+ MB
#      country  price                                        description  points
# 0   Portugal   15.0  This is ripe and fruity, a wine that is smooth...      87
# 2         US   13.0  Pineapple rind, lemon pith and orange blossom ...      87
# 3         US   65.0  Much like the regular bottling from 2012, this...      87
# 9         US   19.0  Soft, supple plum envelopes an oaky structure ...      87
# 11        US   34.0  Slightly reduced, this wine offers a chalky, t...      87

# %% [markdown]
# #### Create a Simpler Points System
# The points range from 80 - 100, however, I'm sure if you tasted a wine, let's say a merlot, rated at 87 and another merlot rated at 88, you wouldn't be able to taste the difference. Let's bin them using the standard deviation = 3

# %%
#Bin the points using the standard deviation = 3
def transform_points_simplified(points):
    if points < 84:
        return 1 #low quality wine
    elif points >= 84 and points < 88:
        return 2 #low-medium quality wine
    elif points >= 88 and points < 92:
        return 3 #medium quality wine
    elif points >= 92 and points < 96:
        return 4 #medium-high quality wine
    else:
        return 5 #the finest of wines

# %%
#Apply the transformation from above
data = data.assign(points_simplified = data['points'].apply(transform_points_simplified))
data.head()
# Out:
#      country  price                                        description  \
# 0   Portugal   15.0  This is ripe and fruity, a wine that is smooth...
# 2         US   13.0  Pineapple rind, lemon pith and orange blossom ...
# 3         US   65.0  Much like the regular bottling from 2012, this...
# 9         US   19.0  Soft, supple plum envelopes an oaky structure ...
# 11        US   34.0  Slightly reduced, this wine offers a chalky, t...
#
#     points  points_simplified
# 0       87                  2
# 2       87                  2
# 3       87                  2
# 9       87                  2
# 11      87                  2

# %% [markdown]
# ## Model Selection
# I'm going to perform a tf-idf on the description and see if we can predict the points_simplified using Random Forsts

# %% [markdown]
# ### 1. tf-idf Model Implementation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text
from nltk.corpus import stopwords
from nltk.corpus import stopwords

punc = ['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}',"%",]
stop = set(stopwords.words('english'))
stop.update(punc)

desc = data['description'].values
tfidf = TfidfVectorizer(stop_words = stop_words, token_pattern = u'(?ui)\\b\\w*[a-z]+\\w*\\b')

#Above, I used regex to adjust the default token_pattern. Basically, I'm making sure the string pattern matches
#a word and contains at least one letter.

X = tfidf.fit_transform(desc)

words = tfidf.get_feature_names()

print(words)
# Out:
# ['05s', '06s', '07s', '08s', '09s', '100ml', '100th', '107th', '10g', '10th', '11th', '12g', '12th', '130th', '13g', '13th', '14g', '14th', '1500s', '150th', '155g', '159g', '15g', '15s', '15th', '160g', '16g', '16th', '1700s', '170g', '17th', '1800s', '1820s', '1840s', '1850s', '1860s', '187ml', '1880s', '188th', '1890s', '189g', '18th', '1920s', '1930s', '1950s', '1960s', '1970s', '1980s', '1990s', '1998s', '19th', '1st', '1ère', '2000s', '2004s', '2005s', '2006s', '2007s', '2008s', '2009s', '2010s', '2011s', '2012s', '2013s', '2014s', '2015s', '2020s', '20g', '20th', '21st', '22g', '23g', '24g', '25g', '25th', '26g', '2a', '2cv', '2g', '2l', '30g', '30th', '33rd', '34th', '35th', '375ml', '3bb', '3l', '3rd', '40th', '41st', '45g', '47g', '4g', '500l', '500th', '50g', '50th', '54g', '5g', '60th', '6g', '6th', '70g', '70s', '7th', '7up', '800th', '80s', '80th', '84s', '8g', '8th', '90s', '90th', '97s', '98s', '99s', '9g', 'a1611', 'a307', 'aa', 'aand', 'aaron', 'abacela', 'abadal', 'abadia', 'abandon', 'abandoned', 'abate', 'abbey', 'abbot', 'abbott', 'abbreviated', 'abc', 'abeille', 'abeja', 'abel', 'abernathy', 'aberrant', 'abetina', 'abeyance', 'abide', 'abilio', 'abilities', 'ability', 'abiouness', 'able', 'ably', 'abnormal', 'aboard', 'abondante', 'aboriginal', 'abound', 'abounds', 'abouriou', 'abovde', 'abrasive', 'abrasiveness', 'abreu', 'abrigo', 'abroad', 'abrupt', 'abruptly', 'abruptness', 'abruzzo', 'absberg', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'absorbed', 'absurd', 'abtsberg', 'abundance', 'abundant', 'abundantly', 'abused', 'abuts', 'abuzz', 'abv', 'acacia', 'academic', 'acadia', 'acai', 'acate', 'acccessible', 'accelerates', 'accent', 'accented', 'accenting', 'accents', 'accentuate', 'accentuated', 'accentuates', 'accentuating', 'acceptability', 'acceptable', 'acceptance', 'access', 'accesses', 'accessibile', 'accessibility', 'accessible', 'accessibly', 'accessorized', 'accetnes', 'accident', 'accidental', 'acciderba', 'acclaimed', 'accolade', 'accolades', 'accommodates', 'accompained', 'accompanied', 'accompanies', 'accompaniment', 'accompaniments', 'accompany', 'accompanying', 'accomplish', 'accomplished', 'accomplishes', 'accomplishment', 'accompnaied', 'accordance', 'accorded', 'according', 'accordingly', 'accordion', 'account', 'accountant', 'accounted', 'accounting', 'accounts', 'accumulate', 'accumulating', 'accurate', 'accurately', 'accuse', 'accustomed', 'ace', 'aceri', 'acetic', 'acetone', 'achaval', 'achieve', 'achieved', 'achievement', 'achieves', 'achieving', 'achilles', 'aching', 'achingly', 'aciar', 'acid', 'acidhounds', 'acidic', 'acidically', 'acidicy', 'acididty', 'acidification', 'acidified', 'acidify', 'acidity', 'acidiy', 'acids', 'acidty', 'aciprestes', 'acitity', 'ackhurst', 'acknowledged', 'acknowledges', 'aconcagua', 'acorn', 'acorns', 'acquaintance', 'acquire', 'acquired', 'acquires', 'acquiring', 'acquit', 'acquitted', 'acre', 'acreage', 'acres', 'acrid', 'acrobat', 'acrobatics', 'act', 'acting', 'action', 'active', 'actively', 'actor', 'actors', 'actress', 'acts', 'actual', 'actuality', 'actually', 'acute', 'acutely', 'ad', 'adage', 'adam', 'adamant', 'adams', 'adaptability', 'adaptable', 'adaptation', 'adapted', 'adastra', 'add', 'addamo', 'added', 'addiction', 'addictive', 'addictively', 'addicts', 'adding', 'addition', 'additional', 'additionally', 'additions', 'additives', 'address', 'adds', 'ade', 'adega', 'adelaida', 'adelaide', 'adele', 'adelsheim', 'adelsheims', 'adept', 'adequate', 'adequately', 'adhere', 'adherence', 'adheres', 'adhesive', 'adige', 'adjacent', 'adjectives', 'adjoining', 'adjoins', 'adjusted', 'adjusts', 'admirable', 'admirably', 'admiral', 'admiration', 'admire', 'admired', 'admirers', 'admit', 'admittance', 'admitted', 'admittedly', 'admitting', 'ado', 'adobe', 'adolescence', 'adolescent', 'adopted', 'adopts', 'adore', 'adored', 'adorn', 'adorned', 'adorning', 'adornments', 'adorns', 'adquate', 'adrianna', 'adriatic', 'adrienne', 'adro ...

# %% [markdown]
# #### Thoughts
# Looks like some numbers are still coming through. This will probably hurt the model
#
# //ToDo: remove any numbers in the feature_names

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

y = data['points_simplified']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 43)

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

predictions = rfc.predict(X_test)

ct = pd.crosstab(y_test,predictions)
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[ 112  436   53    2    0]
#  [  57 2703 1306   52    0]
#  [   8 1387 3213  300    0]
#  [   2  162 1433  483    1]
#  [   0    2   31   38    0]]
#              precision    recall  f1-score   support
#
#           1       0.63      0.19      0.29       603
#           2       0.58      0.66      0.61      4118
#           3       0.53      0.65      0.59      4908
#           4       0.55      0.23      0.33      2081
#           5       0.00      0.00      0.00        71
#
# avg / total       0.55      0.55      0.53     11781

# %% [markdown]
# #### Thoughts
# In this case, I would fail to reject the H0
#
# The precision isn't that great. I'm thinking tf-idf might be too complex or I didn't implement it correctly. I was having issues with removing numbers in the description. I need to research this and probably some more on Tokenization to create topics.

# %% [markdown]
# ### Project Synopsis
# Write a synopsis explaining what happened in your model, and the short-comings of it (you definitely have some). Consider future models you would have liked to design, why they might work better, or why you feel this is a promising start and could be useful if you had more time.

# %% [markdown]
# ## 5. Conclusion & Further Development
#
# Talk about your project as whole, was it what you expected, did your results show any promise, or would you trash this project and start new (this happens often).
#
# Talk about real life considerations. Would this model be worth developing in a business setting. Consider things like time and money. For example, if a current logistic regression was giving a 78% accuracy metric, is it really worth getting 80% accuracy by spending countless more hours designing a neural network.
#
# Most importantly, consider the business and business problem when answering the above questions. For myself, if I'm designing an ML model to trade in financial market, is this good enough to put money on it, would you stake part of your income and retirement plan on it?
#
# Talk about any lasting impressions this project gave you, or things you found out that you didn't know before (this should happen).
